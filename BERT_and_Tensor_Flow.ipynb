# %% [markdown]
# <a href="https://colab.research.google.com/github/pierredevillers/DMML2022_Coop/blob/main/BERT_and_Tensor_Flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BERT and Tensor Flow for Text Classification**
#
# In this notebook, we decided to implement a classification model which combines different BERT-like models imported from the TensorFlow Hub in order to get a multilingual text classifier. This model gave us the highest accuracy score and is working with word embeddings. We are following the following steps for the implementation of the model :
#
# 1. Load the data and restructure it in a satisfying format
# 2. Install and import all the necessary packages and tools for the set-up of the model
# 3. Preprocessing and preparation of the data for the training
# 4. Set-up of the model
# 5. Training of the model
# 6. Prediction on the unlabelled data

# %% [markdown]
# ##1. Data loading and structuring
#
# In this part, we are downloading the different CSV files from our GitHub repository and restructuring it in order to replace the levels of French by numeric values.

# %%
# Connect the colab to the Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Import and read the training data in a dataframe 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/pierredevillers/DMML2022_Coop/main/CSV_files/training_data.csv')
df.head()
# Out:
#    id                                           sentence difficulty
# 0   0  Les coûts kilométriques réels peuvent diverger...         C1
# 1   1  Le bleu, c'est ma couleur préférée mais je n'a...         A1
# 2   2  Le test de niveau en français est sur le site ...         A1
# 3   3           Est-ce que ton mari est aussi de Boston?         A1
# 4   4  Dans les écoles de commerce, dans les couloirs...         B1

# %%
# Replace the difficulty levels by numerical values
df['Labels'] = df['difficulty'].map({'A1': 0,
                                            'A2': 1,
                                            'B1': 2,
                                            'B2': 3,
                                            'C1': 4,
                                            'C2' : 5})

# Drop unused column
df = df.drop(["difficulty"], axis=1)

df.head()
# Out:
#    id                                           sentence  Labels
# 0   0  Les coûts kilométriques réels peuvent diverger...       4
# 1   1  Le bleu, c'est ma couleur préférée mais je n'a...       0
# 2   2  Le test de niveau en français est sur le site ...       0
# 3   3           Est-ce que ton mari est aussi de Boston?       0
# 4   4  Dans les écoles de commerce, dans les couloirs...       2

# %% [markdown]
# ##2. Setup and import of the different tools and packages needed for the model
#
# In this part, we are installing and importing the different packages that contains the needed documentation for the implementation of the model.

# %%
# Installing kaggle 
# %%capture
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle) (7.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (3.0.4)

# %%
# Installing the needed packages from the TensorFlow software library
# %%capture
! pip install "tensorflow>=1.7.0"
! pip install tensorflow-hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow>=1.7.0 in /usr/local/lib/python3.8/dist-packages (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (1.51.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (1.6.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (2.11.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (4.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (22.12.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (0.28.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (14.0.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (21.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (57.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (2.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (1.21.6)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=1.7.0) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=1.7.0) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (2.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (2.23.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=1.7.0) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow>=1.7.0) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.8/dist-packages (0.12.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-hub) (1.21.6)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-hub) (3.19.6)

# %%
# %%capture
! pip install tensorflow-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-text in /usr/local/lib/python3.8/dist-packages (2.11.0)
# Requirement already satisfied: tensorflow<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-text) (2.11.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-text) (0.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (22.12.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (1.51.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (4.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (2.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (0.28.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (1.21.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (2.1.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (14.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.11.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow<2.12,>=2.11.0->tensorflow-text) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (2.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (2.23.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.11.0->tensorflow-text) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow<2.12,>=2.11.0->tensorflow-text) (3.0.9)

# %% [markdown]
# For processing power purposes, we decided to make our model run on an available GPU through Colab.

# %%
# Verifying the availability of the GPU 

import torch
torch.cuda.is_available()

# %%
# Testing the GPU 

import tensorflow as tf
tf.test.gpu_device_name()

# %%
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
import tensorflow_text as text
from keras import backend as K
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ##3. Preprocessing and preparation of the data for the training
#
# In this part, we are splitting and reshaping our data in order for it to be usable for the model. We first create the different train and test splits of the data and we then apply the BERT embeddings on it in order to process the sentences as vectors for the model.

# %%
# Defining the number of classes that we want in our model 

num_classes = len(df["Labels"].value_counts())

#Transforming the classes into binary class matrixes 
y = tf.keras.utils.to_categorical(df["Labels"].values, num_classes=num_classes)

# Splitting the training data
x_train, x_test, y_train, y_test = train_test_split(df['sentence'], y, test_size=0.01,  random_state=0)

# %%
# Import of the layers of the model and definition of a function applying them

preprocessor = hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder-cmlm/multilingual-preprocess/2")
encoder = hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder-cmlm/multilingual-base/1")


def get_embeddings(sentences):
  '''return BERT-like embeddings of input text
  Args:
    - sentences: list of strings
  Output:
    - BERT-like embeddings: tf.Tensor of shape=(len(sentences), 768)
  '''
  preprocessed_text = preprocessor(sentences)
  return encoder(preprocessed_text)['pooled_output']

# Checking of the function on one line of the data

get_embeddings([
    "Les coûts kilométriques réels peuvent diverger sensiblement des valeurs moyennes en fonction du moyen de transport utilisé, du taux d'occupation ou du taux de remplissage, de l'infrastructure utilisée, de la topographie des lignes, du flux de trafic, etc."]
)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# <tf.Tensor: shape=(1, 768), dtype=float32, numpy=
# array([[-3.63910437e-01,  2.15399176e-01, -5.70777893e-01,
#         -4.57450926e-01,  1.94023952e-01, -3.41218174e-01,
#         -4.04711477e-02, -2.72382379e-01, -2.03393146e-01,
#          4.53949198e-02, -7.60403574e-01, -3.80386919e-01,
#          5.12294769e-02, -3.07878196e-01, -6.63932681e-01,
#         -3.10593545e-01, -1.94577761e-02, -3.24811310e-01,
#          9.24890582e-03, -6.82702288e-02,  4.39894229e-01,
#          1.90010771e-01, -1.96524501e-01,  3.22621018e-01,
#         -2.80322023e-02, -9.78579104e-01,  2.13870909e-02,
#         -7.58466840e-01, -3.53789598e-01, -4.06974286e-01,
#          2.11517617e-01, -6.07400000e-01, -3.57876718e-01,
#         -4.86232907e-01, -5.95954359e-01,  4.41088751e-02,
#         -2.92998385e-02,  2.86389053e-01, -5.22589326e-01,
#          5.57419419e-01, -1.57448575e-01, -3.20106953e-01,
#         -4.56426620e-01,  3.34122509e-01,  1.46663105e-02,
#          3.74394320e-02, -1.25981063e-01, -2.15156108e-01,
#         -3.31009775e-01, -2.10297421e-01,  6.09823130e-02,
#          9.62748885e-01,  4.10048440e-02,  7.12572858e-02,
#         -4.35477287e-01,  5.00209630e-02, -1.73141852e-01,
#          1.55065089e-01,  6.97434619e-02,  2.63149232e-01,
#          8.60062778e-01, -4.83927056e-02, -6.16960786e-02,
#         -8.46620202e-01, -1.31340235e-01, -7.18410239e-02,
#         -1.79858822e-02, -1.11102179e-01, -9.98886079e-02,
#         -5.70250750e-02, -3.44807476e-01, -4.15781513e-03,
#         -3.13587695e-01, -8.47597346e-02, -4.07316536e-01,
#          6.14990532e-01,  9.09850970e-02,  1.11705326e-01,
#         -1.89326666e-02,  7.87452906e-02,  2.18806486e-03,
#          2.17147160e+00, -1.77220538e-01, -1.34274751e-01,
#         -7.08085239e-01,  1.12699740e-01,  1.53672889e-01,
#         -7.34502435e-01, -3.71629268e-01,  5.03125079e-02,
#         -4.88572836e-01, -5.95926605e-02, -2.75533199e-02,
#         -3.36048424e-01, -3.50909263e-01, -5.45199931e-01,
#          2.33009368e-01,  2.95020968e-01,  5.86613901e-02,
#          1.13930018e-05, -3.29962760e-01,  2.34611228e-01,
#          5.25110662e-01, -1.75481692e-01,  2.05563140e+00,
#          1.54524118e-01, -4.36974913e-01, -3.16005677e-01,
#          8.79371017e-02,  1.72322661e-01, -1.52288184e-01,
#         -2.23095432e-01, -3.18095922e-01, -5.02216995e-01,
#         -1.43863961e-01, -2.35313866e-02,  1.30072877e-01,
#         -2.35470328e-02,  9.79187489e-02, -9.56417263e-01,
#         -2.11224079e-01, -4.60630417e-01, -2.01941654e-03,
#         -7.20333695e-01,  5.08645058e-01, -1.14377953e-01,
#         -1.42384856e-03, -5.86327732e-01, -6.62351608e-01,
#         -7.93637931e-01, -4.72951859e-01,  7.50928074e-02,
#         -3.07085723e-01, -1.82340413e-01,  4.40205485e-01,
#         -3.94062340e-01,  2.32506663e-01, -1.14295661e-01,
#         -7.58238196e-01, -2.05430277e-02, -4.05686587e-01,
#          3.35253030e-01, -6.98901534e-01,  3.46526474e-01,
#         -2.79243588e-01, -4.41345721e-01,  3.40248883e-01,
#         -1.77425057e-01, -7.28259921e-01, -1.25269830e-01,
#          2.07022890e-01,  1.17800757e-01, -5.61948180e-01,
#          1.20515399e-01,  1.77833006e-01,  1.38348654e-01,
#         -2.71867067e-01, -8.73067454e-02, -7.70945251e-01,
#         -1.31183878e-01, -1.76944047e-01, -9.09923203e-03,
#         -1.44785136e-01, -8.39539349e-01, -3.06621730e-01,
#         -1.37568384e-01, -1.17336981e-01, -4.59478527e-01,
#         -1.95635170e-01, -2.74442315e-01,  1.40293241e-02,
#          1.02760188e-01, -8.11686516e-01, -2.89565176e-01,
#         -4.21074867e-01, -3.56323272e-01, -2.13579327e-01,
#         -7.29572922e-02, -4.91751358e-02, -3.35141152e-01,
#          2.56031930e-01, -2.00663120e-01, -4.38867867e-01,
#         -3.94560635e-01, -5.44082284e-01,  2.34448642e-01,
#         -2.30200678e-01,  1.86546333e-02,  3.91830921e-01,
#         -2.59244293e-01, -4.12199646e-01,  2.35820264e-02,
#          7.35231340e-01,  2.94011801e-01, -2.04875723e-01,
#         -1.93426341e-01, -2.13243574e-01,  1.69218376e-01,
#         -3.79330426e-01,  7.04582334e-02,  1.40442342e-01,
#         -2.99295008e-01, -4.52446453e-02, -6.82522476e-01]], dtype=float32)>

# %%
# Definition of the different descriptive statistics for the performance of the model

def balanced_recall(y_true, y_pred):
    """This function calculates the balanced recall metric
    recall = TP / (TP + FN)
    """
    recall_by_class = 0
    # iterate over each predicted class to get class-specific metric
    for i in range(y_pred.shape[1]):
        y_pred_class = y_pred[:, i]
        y_true_class = y_true[:, i]
        true_positives = K.sum(K.round(K.clip(y_true_class * y_pred_class, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true_class, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        recall_by_class = recall_by_class + recall
    return recall_by_class / y_pred.shape[1]

def balanced_precision(y_true, y_pred):
    """This function calculates the balanced precision metric
    precision = TP / (TP + FP)
    """
    precision_by_class = 0
    # iterate over each predicted class to get class-specific metric
    for i in range(y_pred.shape[1]):
        y_pred_class = y_pred[:, i]
        y_true_class = y_true[:, i]
        true_positives = K.sum(K.round(K.clip(y_true_class * y_pred_class, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred_class, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        precision_by_class = precision_by_class + precision
    # return average balanced metric for each class
    return precision_by_class / y_pred.shape[1]

def balanced_f1_score(y_true, y_pred):
    """This function calculates the F1 score metric"""
    precision = balanced_precision(y_true, y_pred)
    recall = balanced_recall(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %% [markdown]
# ##4. Set-up of the model
#
# In this part, we defined all the features to define the model before training it on our splitted data.

# %%
# Definition of the model's parameters

i = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
x = preprocessor(i)
x = encoder(x)
x = tf.keras.layers.Dropout(0.01, name="dropout")(x['pooled_output'])
x = tf.keras.layers.Dense(num_classes, activation='softmax', name="output")(x)

model = tf.keras.Model(i, x)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ##5. Training of the model
#
# Now that the model has been set-up and that the parameters have been defined, we train it on the training data. We also define a function that stops the training if we notice that the accuracy is not getting better for several iterations.

# %%
n_epochs = 20

METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
      balanced_recall,
      balanced_precision,
      balanced_f1_score
]

earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", 
                                                      patience = 3,
                                                      restore_best_weights = True)

model.compile(optimizer = "adam",
              loss = "categorical_crossentropy",
              metrics = METRICS)

model_fit = model.fit(x_train, 
                      y_train, 
                      epochs = n_epochs,
                      validation_data = (x_test, y_test),
                      callbacks = [earlystop_callback])
# Out:
# Epoch 1/20
# 120/120 [==============================] - 75s 431ms/step - loss: 1.4794 - accuracy: 0.3898 - balanced_recall: 0.0588 - balanced_precision: 0.1492 - balanced_f1_score: 0.0792 - val_loss: 1.3225 - val_accuracy: 0.4406 - val_balanced_recall: 0.1463 - val_balanced_precision: 0.2392 - val_balanced_f1_score: 0.1783
# Epoch 2/20
# 120/120 [==============================] - 49s 412ms/step - loss: 1.2055 - accuracy: 0.5096 - balanced_recall: 0.1721 - balanced_precision: 0.3621 - balanced_f1_score: 0.2290 - val_loss: 1.2136 - val_accuracy: 0.5083 - val_balanced_recall: 0.1804 - val_balanced_precision: 0.3815 - val_balanced_f1_score: 0.2416
# Epoch 3/20
# 120/120 [==============================] - 49s 412ms/step - loss: 1.1222 - accuracy: 0.5544 - balanced_recall: 0.2412 - balanced_precision: 0.4794 - balanced_f1_score: 0.3161 - val_loss: 1.1714 - val_accuracy: 0.5094 - val_balanced_recall: 0.2317 - val_balanced_precision: 0.4434 - val_balanced_f1_score: 0.2995
# Epoch 4/20
# 120/120 [==============================] - 49s 408ms/step - loss: 1.0697 - accuracy: 0.5737 - balanced_recall: 0.2825 - balanced_precision: 0.5360 - balanced_f1_score: 0.3651 - val_loss: 1.1417 - val_accuracy: 0.5167 - val_balanced_recall: 0.2603 - val_balanced_precision: 0.5053 - val_balanced_f1_score: 0.3386
# Epoch 5/20
# 120/120 [==============================] - 50s 419ms/step - loss: 1.0381 - accuracy: 0.5854 - balanced_recall: 0.3262 - balanced_precision: 0.6030 - balanced_f1_score: 0.4189 - val_loss: 1.1276 - val_accuracy: 0.5260 - val_balanced_recall: 0.2939 - val_balanced_precision: 0.5793 - val_balanced_f1_score: 0.3858
# Epoch 6/20
# 120/120 [==============================] - 50s 419ms/step - loss: 1.0105 - accuracy: 0.5966 - balanced_recall: 0.3580 - balanced_precision: 0.6112 - balanced_f1_score: 0.4468 - val_loss: 1.1254 - val_accuracy: 0.5250 - val_balanced_recall: 0.3055 - val_balanced_precision: 0.5303 - val_balanced_f1_score: 0.3829
# Epoch 7/20
# 120/120 [==============================] - 51s 424ms/step - loss: 0.9937 - accuracy: 0.6039 - balanced_recall: 0.3715 - balanced_precision: 0.6593 - balanced_f1_score: 0.4705 - val_loss: 1.1229 - val_accuracy: 0.5229 - val_balanced_recall: 0.3062 - val_balanced_precision: 0.5108 - val_balanced_f1_score: 0.3789
# Epoch 8/20
# 120/120 [==============================] - 51s 422ms/step - loss: 0.9773 - accuracy: 0.6102 - balanced_recall: 0.3854 - balanced_precision: 0.6619 - balanced_f1_score: 0.4827 - val_loss: 1.1058 - val_accuracy: 0.5333 - val_balanced_recall: 0.3333 - val_balanced_precision: 0.5665 - val_balanced_f1_score: 0.4160
# Epoch 9/20
# 120/120 [==============================] - 49s 411ms/step - loss: 0.9673 - accuracy: 0.6107 - balanced_recall: 0.4068 - balanced_precision: 0.6645 - balanced_f1_score: 0.5006 - val_loss: 1.1248 - val_accuracy: 0.5281 - val_balanced_recall: 0.3456 - val_balanced_precision: 0.5681 - val_balanced_f1_score: 0.4261
# Epoch 10/20
# 120/120 [==============================] - 51s 422ms/step - loss: 0.9540 - accuracy: 0.6107 - balanced_recall: 0.4160 - balanced_precision: 0.6928 - balanced_f1_score: 0.5174 - val_loss: 1.1029 - val_accuracy: 0.5229 - val_balanced_recall: 0.3383 - val_balanced_precision: 0.5311 - val_balanced_f1_score: 0.4099
# Epoch 11/20
# 120/120 [==============================] - 51s 426ms/step - loss: 0.9458 - accuracy: 0.6271 - balanced_recall: 0.4225 - balanced_precision: 0.6786 - balanced_f1_score: 0.5168 - val_loss: 1.0947 - val_accuracy: 0.5479 - val_balanced_recall: 0.3534 - val_balanced_precision: 0.5910 - val_balanced_f1_score: 0.4376
# Epoch 12/20
# 120/120 [==============================] - 49s 412ms/step - loss: 0.9396 - accuracy: 0.6206 - balanced_recall: 0.4264 - balanced_precision: 0.7023 - balanced_f1_score: 0.5270 - val_loss: 1.1029 - val_accuracy: 0.5406 - val_balanced_recall: 0.3593 - val_balanced_precision: 0.5753 - val_balanced_f1_score: 0.4380
# Epoch 13/20
# 120/120 [==============================] - 50s 421ms/step - loss: 0.9300 - accuracy: 0.6271 - balanced_recall: 0.4369 - balanced_precision: 0.6859 - balanced_f1_score: 0.5297 - val_loss: 1.0941 - val_accuracy: 0.5323 - val_balanced_recall: 0.3820 - val_balanced_precision: 0.5911 - val_balanced_f1_score: 0.4593
# Epoch 14/20
# 120/120 [==============================] - 51s 425ms/step - loss: 0.9229 - accuracy: 0.6216 - balanced_recall: 0.4561 - balanced_precision: 0.7051 - balanced_f1_score: 0.5509 - val_loss: 1.0928 - val_accuracy: 0.5448 - val_balanced_recall: 0.3701 - val_balanced_precision: 0.5838 - val_balanced_f1_score: 0.4482
# Epoch 15/20
# 120/120 [==============================] - 53s 439ms/step - loss: 0.9128 - accuracy: 0.6310 - balanced_recall: 0.4519 - balanced_precision: 0.6954 - balanced_f1_score: 0.5447 - val_loss: 1.0926 - val_accuracy: 0.5302 - val_balanced_recall: 0.3867 - val_balanced_precision: 0.5740 - val_balanced_f1_score: 0.4580
# Epoch 16/20
# 120/120 [==============================] - 50s 417ms/step - loss: 0.9080 - accuracy: 0.6391 - balanced_recall: 0.4587 - balanced_precision: 0.6987 - balanced_f1_score: 0.5514 - val_loss: 1.1017 - val_accuracy: 0.5458 - val_balanced_recall: 0.3922 - val_balanced_precision: 0.5872 - val_balanced_f1_score: 0.4661
# Epoch 17/20
# 120/120 [==============================] - 49s 413ms/step - loss: 0.9033 - accuracy: 0.6349 - balanced_recall: 0.4701 - balanced_precision: 0.6965 - balanced_f1_score: 0.5578 - val_loss: 1.0979 - val_accuracy: 0.5292 - val_balanced_recall: 0.3717 - val_balanced_precision: 0.5624 - val_balanced_f1_score: 0.4434
# Epoch 18/20
# 120/120 [==============================] - 50s 416ms/step - loss: 0.8931 - accuracy: 0.6401 - balanced_recall: 0.4695 - balanced_precision: 0.7020 - balanced_f1_score: 0.5597 - val_loss: 1.1105 - val_accuracy: 0.5292 - val_balanced_recall: 0.3809 - val_balanced_precision: 0.5697 - val_balanced_f1_score: 0.4521

# %%
test_df = pd.read_csv('https://raw.githubusercontent.com/pierredevillers/DMML2022_Coop/main/CSV_files/unlabelled_test_data.csv')

reviews = test_df['sentence']

def predict_class(reviews):
  '''predict class of input text
  Args:
    - reviews (list of strings)
  Output:
    - class (list of int)
  '''
  return [np.argmax(pred) for pred in model.predict(reviews)]

predict_class(reviews)
# Out:
#    id                                           sentence
# 0   0  Nous dûmes nous excuser des propos que nous eû...
# 1   1  Vous ne pouvez pas savoir le plaisir que j'ai ...
# 2   2  Et, paradoxalement, boire froid n'est pas la b...
# 3   3  Ce n'est pas étonnant, car c'est une saison my...
# 4   4  Le corps de Golo lui-même, d'une essence aussi...

# %%
x_new = test_df.sentence
y_new_pred = predict_class(reviews)

test_df['difficulty'] = y_new_pred
test_df['difficulty'] = test_df['difficulty'].replace({0:'A1', 1:'A2', 2: 'B1', 3:'B2', 4:'C1', 5:'C2'})

test_df
# Out:
# 38/38 [==============================] - 11s 308ms/step
#         id                                           sentence difficulty
# 0        0  Nous dûmes nous excuser des propos que nous eû...         C2
# 1        1  Vous ne pouvez pas savoir le plaisir que j'ai ...         A2
# 2        2  Et, paradoxalement, boire froid n'est pas la b...         B2
# 3        3  Ce n'est pas étonnant, car c'est une saison my...         B1
# 4        4  Le corps de Golo lui-même, d'une essence aussi...         C2
# ...    ...                                                ...        ...
# 1195  1195  C'est un phénomène qui trouve une accélération...         B1
# 1196  1196  Je vais parler au serveur et voir si on peut d...         A2
# 1197  1197  Il n'était pas comme tant de gens qui par pare...         C2
# 1198  1198      Ils deviennent dangereux pour notre économie.         B2
# 1199  1199  Son succès a généré beaucoup de réactions néga...         B2
#
# [1200 rows x 3 columns]

# %%
test_df = test_df.drop(columns=['sentence'])

# %%
test_df
# Out:
#         id difficulty
# 0        0         C2
# 1        1         A2
# 2        2         B2
# 3        3         B1
# 4        4         C2
# ...    ...        ...
# 1195  1195         B1
# 1196  1196         A2
# 1197  1197         C2
# 1198  1198         B2
# 1199  1199         B2
#
# [1200 rows x 2 columns]

# %%
test_df.to_csv('Group_Coop_BERT.csv', index=False)
test_df.to_csv('https://raw.githubusercontent.com/pierredevillers/DMML2022_Coop/main/CSV_files/Group_Coop_BERT.csv', index=False)
